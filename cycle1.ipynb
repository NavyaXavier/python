# %%
a=1
print("the value of",a,"is of the type",type(a))
b="hello"
print("the value of",b,"is of the type",type(b))
c=3.14
print("the value of",c,"is of the type",type(c))
d=2j
print("the value of",d,"is of the type",type(d))
e={"ads","web","python"}
print("the value of",e,"is of the type",type(e))
f=("ads","web","python")
print("the value of",f,"is of the type",type(f))
g=["ads","web","python"]
print("the value of",g,"is of the type",type(g))
h=range(5)
print("the value of",h,"is of the type",type(h))
i=True
print("the value of",i,"is of the type",type(i))
# Out:
# the value of 1 is of the type <class 'int'>
# the value of hello is of the type <class 'str'>
# the value of 3.14 is of the type <class 'float'>
# the value of 2j is of the type <class 'complex'>
# the value of {'python', 'ads', 'web'} is of the type <class 'set'>
# the value of ('ads', 'web', 'python') is of the type <class 'tuple'>
# the value of ['ads', 'web', 'python'] is of the type <class 'list'>
# the value of range(0, 5) is of the type <class 'range'>
# the value of True is of the type <class 'bool'>

# %%
print("Hello,World!")
# Out:
# Hello,World!

# %%
x=int(input("enter a integer value:"))
print(x)
# Out:
# enter a integer value:5
# 5

# %%
x=int(input("enter value of first integer:"))
y=int(input("enter value of second integer:"))
z=x+y
print("sum:",z)
# Out:
# enter value of first integer:5
# enter value of second integer:9
# sum: 14

# %%
x=float(input("enter first float value:"))
y=float(input("enter second float value:"))
z=x*y
print("product :",z)
# Out:
# enter first float value:3.0
# enter second float value:5.0
# product : 15.0

# %%
a=int(input("enter the first value:"))
b=int(input("enter the second value:"))
q=a//b
print("quotient:",q)
r=a%b
print("remainder:",r)
# Out:
# enter the first value:10
# enter the second value:2
# quotient: 5
# remainder: 0

# %%
x=float(input("enter the first number :"))
y=float(input("enter the second number :"))
print("value of first number before swapping:",x)
print("value of second number before swapping:",y)
z=x
x=y
y=z
print("value of first number after swapping :",x)
print("value of second number after swapping :",y)
# Out:
# enter the first number :1
# enter the second number :9
# value of first number before swapping: 1.0
# value of second number before swapping: 9.0
# value of first number after swapping : 9.0
# value of second number after swapping : 1.0

# %%
x=int(input("enter any number:"))
y=x%2
if y==0:
  print(x,"is an even number")
else:
  print(x,"is an odd number")
# Out:
# enter any number:22
# 22 is an even number

# %%
ch=input("enter any character:")
if(ch=='A' or ch=='E' or ch=='I' or ch=='O' or ch=='U' or ch=='a' or ch=='e' or ch=='i' or ch=='o' or ch=='u'):
  print(ch,"is a vowel")
else:
  print(ch,"is a consonant")
# Out:
# enter any character:n
# n is a consonant

# %%
a=float(input("enter the first number :"))
b=float(input("enter the second number :"))
c=float(input("enter the third number : "))
if (a>b) and (a>c):
  print(a,"is the largest number")
elif (b>a) and (b>c):
  print(b,"is the largest number")
else :
  print(c,"is the largest number")
# Out:
# enter the first number :45
# enter the second number :56
# enter the third number : 77
# 77.0 is the largest number

# %%
yr=int(input("enter a year :"))
if((yr%400==0) or ((yr%4==0) and (yr%100!=0))):
  print(yr,"is a leap year")
else :
  print(yr,"is not a leap year")
# Out:
# enter a year :2020
# 2020 is a leap year

# %%
x=int(input("enter any number :"))
if x>0:
  print(x,"is a positive number")
else :
  print(x,"is a negative number")
# Out:
# enter any number :-1
# -1 is a negative number

# %%
n=int(input("enter any number :"))
if n<0:
  print("print a positive number")
else :
  sum=0
  while (n>0):
    sum+=n
    n-=1
    print("sum of natural numbers is",sum)
# Out:
# enter any number :5
# sum of natural numbers is 5
# sum of natural numbers is 9
# sum of natural numbers is 12
# sum of natural numbers is 14
# sum of natural numbers is 15

# %%
n=int(input("enter any number :"))
fact=1
for i in range(1,n+1):
  fact=fact*i
print("factorial of",n,"is",fact)
# Out:
# enter any number :4
# factorial of 4 is 24

# %%
x=int(input("show the multiplication table of ?"))
for i in range(1,11):
  print(x,'x',i,'=',x*i)
# Out:
# show the multiplication table of ?5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
n=int(input("enter any number:"))
x,y=0,1
count=0
if n<=0:
  print("enter a positive number")
elif n==1:
  print("fibonacci series upto",n,":")
  print(x)
else:
  print("fibonacci sequence :")
  while count<n:
    print(x)
    z=x+y
    x=y
    y=z
    count+=1
# Out:
# enter any number:3
# fibonacci sequence :
# 0
# 1
# 1

# %%
def find_lcm(x,y):
  if x > y:
    greater = x
  else:
    greater =  y
  while(True):
     if((greater % x ==0) and (greater % y ==0)):
       lcm = greater
       break
     greater +=  1
  return lcm
a=int(input("enter the value of first number:"))
b=int(input("enter the value of second number:"))
print("the L.C.M  is",find_lcm(a,b))
# Out:
# enter the value of first number:54
# enter the value of second number:24
# the L.C.M  is 216

# %%
n=int(input("enter any number :"))
count=0
while (n>0):
  count=count+1
  n=n//10
  print("the number of digits in the given number is/are :",count)
# Out:
# enter any number :3
# the number of digits in the given number is/are : 1

# %%
x=int(input("enter any number to be reversed:"))
rev=0
while x>0:
  rev=(rev*10)+(x%10)
  x=x//10
  print("reverse is",rev)
# Out:
# enter any number to be reversed:67
# reverse is 7
# reverse is 76

# %%
n=int(input("enter any positive number:"))
e=int(input("enter the value of exponent:"))
p=1
for i in range(1,e+1):
  p=p*n
print("the power of",n,"^",e,"is",p)
# Out:
# enter any positive number:3
# enter the value of exponent:3
# the power of 3 ^ 3 is 27

# %%
n=int(input("enter any number :"))
rev=0
temp=n
while (temp > 0):
  r=temp%10
  rev=(rev*10)+r
  temp=temp//10
  print("reverse of this given number is",rev)
  if (n==rev):
    print(n,"is a palindrome number")
  else :
    print(n,"is not a palindrome number")
# Out:
# enter any number :121
# reverse of this given number is 1
# 121 is not a palindrome number
# reverse of this given number is 12
# 121 is not a palindrome number
# reverse of this given number is 121
# 121 is a palindrome number
